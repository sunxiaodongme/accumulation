# %%
version_list = [{'name':'2019.11.20', 'code':1001}, {'name':'2019.11.10', 'code':1000}]
version_list.sort(key=lambda v:v['code'], reverse=True)
version_list
# Out:
# [{'name': '2019.11.20', 'code': 1001}, {'name': '2019.11.10', 'code': 1000}]

# %%
for i, v in enumerate(['tic', 'tac', 'toe']):
    print(i, v)
# Out:
# 0 tic
# 1 tac
# 2 toe
